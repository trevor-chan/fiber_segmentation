# %%
# %load_ext autoreload
# %autoreload 2

from modules import *
from data import *
from training import *
from testing import *

# %%
d = CellDataset('datasets/export-2020-06-03T01_52_47.577Z.json')
dataloader = torch.utils.data.DataLoader(d, batch_size=2, shuffle=True, num_workers=0, collate_fn=collate_fn)

# %%
model = get_model_instance_segmentation().cuda()

# %%
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005,
                            momentum=0.9, weight_decay=0.0005)
# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)
losses = []

# %%
train(model, optimizer, dataloader, 100, losses)
# Out:
# Epoch 	 1
# 0.42733579874038696
# 0.42733579874038696
# Epoch 	 2
# 0.42932629585266113
# 0.42932629585266113
# Epoch 	 3
# 0.36327311396598816
# 0.36327311396598816
# Epoch 	 4
# 0.4086433947086334
# 0.4086433947086334
# Epoch 	 5
# 0.37486645579338074
# 0.37486645579338074
# Epoch 	 6
# 0.3651696741580963
# 0.3651696741580963
# Epoch 	 7
# 0.35749509930610657
# 0.35749509930610657
# Epoch 	 8
# 0.38811200857162476
# 0.38811200857162476
# Epoch 	 9
# 0.3842896819114685
# 0.3842896819114685
# Epoch 	 10
# 0.3711538016796112
# 0.3711538016796112
# Epoch 	 11
# 0.3576652407646179
# 0.3576652407646179
# Epoch 	 12
# 0.32059359550476074
# 0.32059359550476074
# Epoch 	 13
# 0.3191863000392914
# 0.3191863000392914
# Epoch 	 14
# 0.32810157537460327
# 0.32810157537460327
# Epoch 	 15
# 0.30349001288414
# 0.30349001288414
# Epoch 	 16
# 0.3831444978713989
# 0.3831444978713989
# Epoch 	 17
# 0.32352539896965027
# 0.32352539896965027
# Epoch 	 18
# 0.2848392128944397
# 0.2848392128944397
# ...

# %%
test_image = d[0][0]

# %%
import matplotlib.pyplot as plt
out_img = predict(model, test_image)
plt.imshow(out_img)

# %%
model.eval()
with torch.no_grad():
    prediction = model([test_image.to(device)])
