# %%
# %load_ext autoreload
# %autoreload 2

import cv2
import random
import matplotlib.pyplot as plt
from predict import BrightfieldPredictor

# %%
model = BrightfieldPredictor(confidence=0.5)

# %%
im = cv2.imread('input/mega_img.jpeg')

# %%
i = 1000
j = 1500
size=256
cropped_im = im[i:i+size, j:j+size, :]

# %%
prediction = model.predict(cropped_im)
fig, (ax_l, ax_r) = plt.subplots(1, 2, figsize=(10, 20))
ax_l.imshow(cropped_im)
ax_r.imshow(prediction)

# %%
predictions = model.model(cropped_im)

# %%
predictions['instances'].pred_boxes[3]
# Out:
# Boxes(tensor([[  0.4846, 110.3267,  58.5485, 155.7330]], device='cuda:0'))

# %%
type(predictions['instances'])
# Out:
# detectron2.structures.instances.Instances

# %%
from detectron2.structures.instances import Instances
combined = Instances.cat([predictions['instances'], predictions['instances']])

# %%
predictions['instances'] = predictions['instances'] + predictions['instances']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-51ff7db1796b> in <module>
# ----> 1 predictions['instances'] = predictions['instances'] + predictions['instances']
#
# TypeError: unsupported operand type(s) for +: 'Instances' and 'Instances'

# %%
for tile 

i = 1000
j = 1500
size=256
cropped_im = im[i:i+size, j:j+size, :]
